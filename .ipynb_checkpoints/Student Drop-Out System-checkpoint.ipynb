# %%
import numpy as np
import pandas as pd
import random as rd

# %%
df = pd.DataFrame(columns=["Age","Gender","Home Language","Father Occupation","Mother Occupation","Number Of Siblings", "Father Education","Mother Education","School Distance","Means to school", "House Lighting","School Infrustructure", "School Meal per day", "School Cost","Student marks","Family income source","Class Label"])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Home Language, Father Occupation, Mother Occupation, Number Of Siblings, Father Education, Mother Education, School Distance, Means to school, House Lighting, School Infrustructure, School Meal per day, School Cost, Student marks, Family income source, Class Label]
# Index: []

# %%
n=["10-13 years", "13-15 years", "15-18 years", "above 18 years"]
age=rd.choices(n,weights=[7,8,6,1],k=248)

# %%
age
# Out:
# ['10-13 years',
#  '10-13 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '10-13 years',
#  '13-15 years',
#  '15-18 years',
#  'above 18 years',
#  '10-13 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '15-18 years',
#  '13-15 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '13-15 years',
#  '15-18 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '15-18 years',
#  '15-18 years',
#  '10-13 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '15-18 years',
#  '15-18 years',
#  '15-18 years',
#  '13-15 years',
#  '15-18 years',
#  '10-13 years',
#  '15-18 years',
#  '15-18 years',
#  '10-13 years',
#  '15-18 years',
#  '15-18 years',
#  '13-15 years',
#  '13-15 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  'above 18 years',
#  '10-13 years',
#  '10-13 years',
#  '15-18 years',
#  '13-15 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '15-18 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  'above 18 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '10-13 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '10-13 years',
#  '15-18 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '10-13 years',
#  '10-13 years',
#  'above 18 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '15-18 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '15-18 years',
#  '10-13 years',
#  'above 18 years',
#  '10-13 years',
#  '15-18 years',
#  '13-15 years',
#  '13-15 years',
#  '10-13 years',
#  '15-18 years',
#  '15-18 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  'above 18 years',
#  '15-18 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '10-13 years',
#  'above 18 years',
#  '15-18 years',
#  '10-13 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '15-18 years',
#  '13-15 years',
#  '15-18 years',
#  '15-18 years',
#  '15-18 years',
#  'above 18 years',
#  '13-15 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '15-18 years',
#  '13-15 years',
#  '10-13 years',
#  '10-13 years',
#  'above 18 years',
#  '15-18 years',
#  '10-13 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '15-18 years',
#  '13-15 years',
#  '15-18 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '10-13 years',
#  '15-18 years',
#  'above 18 years',
#  '15-18 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '13-15 years',
#  '15-18 years',
#  '15-18 years',
#  '13-15 years',
#  '15-18 years',
#  '10-13 years',
#  '10-13 years',
#  '13-15 years',
#  '15-18 years',
#  'above 18 years',
#  'above 18 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '10-13 years',
#  '10-13 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '15-18 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '15-18 years',
#  '15-18 years',
#  'above 18 years',
#  '10-13 years',
#  '15-18 years',
#  '13-15 years',
#  '10-13 years',
#  '10-13 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '10-13 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '13-15 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '15-18 years',
#  '10-13 years',
#  '10-13 years']

# %%
df.Age = age

# %%
df
# Out:
#              Age Gender Home Language Father Occupation Mother Occupation  \
# 0    10-13 years    NaN           NaN               NaN               NaN
# 1    10-13 years    NaN           NaN               NaN               NaN
# 2    10-13 years    NaN           NaN               NaN               NaN
# 3    15-18 years    NaN           NaN               NaN               NaN
# 4    10-13 years    NaN           NaN               NaN               NaN
# ..           ...    ...           ...               ...               ...
# 243  15-18 years    NaN           NaN               NaN               NaN
# 244  10-13 years    NaN           NaN               NaN               NaN
# 245  15-18 years    NaN           NaN               NaN               NaN
# 246  10-13 years    NaN           NaN               NaN               NaN
# 247  10-13 years    NaN           NaN               NaN               NaN
#
#     Number Of Siblings Father Education Mother Education School Distance  \
# 0                  NaN              NaN              NaN             NaN
# 1                  NaN              NaN              NaN             NaN
# 2                  NaN              NaN              NaN             NaN
# 3                  NaN              NaN              NaN             NaN
# 4                  NaN              NaN              NaN             NaN
# ..                 ...              ...              ...             ...
# 243                NaN              NaN              NaN             NaN
# 244                NaN              NaN              NaN             NaN
# 245                NaN              NaN              NaN             NaN
# 246                NaN              NaN              NaN             NaN
# 247                NaN              NaN              NaN             NaN
#
#     Means to school House Lighting School Infrustructure School Meal per day  \
# 0               NaN            NaN                   NaN                 NaN
# 1               NaN            NaN                   NaN                 NaN
# 2               NaN            NaN                   NaN                 NaN
# 3               NaN            NaN                   NaN                 NaN
# 4               NaN            NaN                   NaN                 NaN
# ..              ...            ...                   ...                 ...
# 243             NaN            NaN                   NaN                 NaN
# 244             NaN            NaN                   NaN                 NaN
# 245             NaN            NaN                   NaN                 NaN
# 246             NaN            NaN                   NaN                 NaN
# 247             NaN            NaN                   NaN                 NaN
#
#     School Cost Student marks Family income source Class Label
# 0           NaN           NaN                  NaN         NaN
# 1           NaN           NaN                  NaN         NaN
# 2           NaN           NaN                  NaN         NaN
# 3           NaN           NaN                  NaN         NaN
# 4           NaN           NaN                  NaN         NaN
# ..          ...           ...                  ...         ...
# 243         NaN           NaN                  NaN         NaN
# 244         NaN           NaN                  NaN         NaN
# 245         NaN           NaN                  NaN         NaN
# 246         NaN           NaN                  NaN         NaN
# 247         NaN           NaN                  NaN         NaN
#
# [248 rows x 17 columns]

# %%
n=["male","female","others"]
gender=rd.choices(n,weights=[49,50,0.3],k=248)
gender
# Out:
# ['female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female']

# %%
df.Gender = gender
df.head()
# Out:
#            Age  Gender Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female           NaN               NaN               NaN
# 1  10-13 years  female           NaN               NaN               NaN
# 2  10-13 years  female           NaN               NaN               NaN
# 3  15-18 years    male           NaN               NaN               NaN
# 4  10-13 years    male           NaN               NaN               NaN
#
#   Number Of Siblings Father Education Mother Education School Distance  \
# 0                NaN              NaN              NaN             NaN
# 1                NaN              NaN              NaN             NaN
# 2                NaN              NaN              NaN             NaN
# 3                NaN              NaN              NaN             NaN
# 4                NaN              NaN              NaN             NaN
#
#   Means to school House Lighting School Infrustructure School Meal per day  \
# 0             NaN            NaN                   NaN                 NaN
# 1             NaN            NaN                   NaN                 NaN
# 2             NaN            NaN                   NaN                 NaN
# 3             NaN            NaN                   NaN                 NaN
# 4             NaN            NaN                   NaN                 NaN
#
#   School Cost Student marks Family income source Class Label
# 0         NaN           NaN                  NaN         NaN
# 1         NaN           NaN                  NaN         NaN
# 2         NaN           NaN                  NaN         NaN
# 3         NaN           NaN                  NaN         NaN
# 4         NaN           NaN                  NaN         NaN

# %%
n=["English","Bangla","Native Language"]
ho_la=rd.choices(n,weights=[5,35,60],k=248)

# %%
df['Home Language']=ho_la
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language               NaN               NaN
# 1  10-13 years  female  Native Language               NaN               NaN
# 2  10-13 years  female  Native Language               NaN               NaN
# 3  15-18 years    male           Bangla               NaN               NaN
# 4  10-13 years    male  Native Language               NaN               NaN
#
#   Number Of Siblings Father Education Mother Education School Distance  \
# 0                NaN              NaN              NaN             NaN
# 1                NaN              NaN              NaN             NaN
# 2                NaN              NaN              NaN             NaN
# 3                NaN              NaN              NaN             NaN
# 4                NaN              NaN              NaN             NaN
#
#   Means to school House Lighting School Infrustructure School Meal per day  \
# 0             NaN            NaN                   NaN                 NaN
# 1             NaN            NaN                   NaN                 NaN
# 2             NaN            NaN                   NaN                 NaN
# 3             NaN            NaN                   NaN                 NaN
# 4             NaN            NaN                   NaN                 NaN
#
#   School Cost Student marks Family income source Class Label
# 0         NaN           NaN                  NaN         NaN
# 1         NaN           NaN                  NaN         NaN
# 2         NaN           NaN                  NaN         NaN
# 3         NaN           NaN                  NaN         NaN
# 4         NaN           NaN                  NaN         NaN

# %%
n=["Unemployed","Agriculture","Freelancer ","Public sector","Private sector","Business","Worker","Immigrant"]
fa_ocu=rd.choices(n,weights=[2,4,4,5,7,6,8,8],k=248)

# %%
df['Father Occupation']= fa_ocu
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed               NaN
# 1  10-13 years  female  Native Language         Immigrant               NaN
# 2  10-13 years  female  Native Language    Private sector               NaN
# 3  15-18 years    male           Bangla    Private sector               NaN
# 4  10-13 years    male  Native Language       Freelancer                NaN
#
#   Number Of Siblings Father Education Mother Education School Distance  \
# 0                NaN              NaN              NaN             NaN
# 1                NaN              NaN              NaN             NaN
# 2                NaN              NaN              NaN             NaN
# 3                NaN              NaN              NaN             NaN
# 4                NaN              NaN              NaN             NaN
#
#   Means to school House Lighting School Infrustructure School Meal per day  \
# 0             NaN            NaN                   NaN                 NaN
# 1             NaN            NaN                   NaN                 NaN
# 2             NaN            NaN                   NaN                 NaN
# 3             NaN            NaN                   NaN                 NaN
# 4             NaN            NaN                   NaN                 NaN
#
#   School Cost Student marks Family income source Class Label
# 0         NaN           NaN                  NaN         NaN
# 1         NaN           NaN                  NaN         NaN
# 2         NaN           NaN                  NaN         NaN
# 3         NaN           NaN                  NaN         NaN
# 4         NaN           NaN                  NaN         NaN

# %%
n=["Home maker","Agriculture","Freelancer","Public sector","Private sector","Business","Worker","Immigrant"]
mo_ocu=rd.choices(n,weights=[9,4,4,6,8,5,6,3],k=248)

# %%
df['Mother Occupation']=mo_ocu
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings Father Education Mother Education School Distance  \
# 0                NaN              NaN              NaN             NaN
# 1                NaN              NaN              NaN             NaN
# 2                NaN              NaN              NaN             NaN
# 3                NaN              NaN              NaN             NaN
# 4                NaN              NaN              NaN             NaN
#
#   Means to school House Lighting School Infrustructure School Meal per day  \
# 0             NaN            NaN                   NaN                 NaN
# 1             NaN            NaN                   NaN                 NaN
# 2             NaN            NaN                   NaN                 NaN
# 3             NaN            NaN                   NaN                 NaN
# 4             NaN            NaN                   NaN                 NaN
#
#   School Cost Student marks Family income source Class Label
# 0         NaN           NaN                  NaN         NaN
# 1         NaN           NaN                  NaN         NaN
# 2         NaN           NaN                  NaN         NaN
# 3         NaN           NaN                  NaN         NaN
# 4         NaN           NaN                  NaN         NaN

# %%
n=["None","Two Children","Three Children","Four or more"]
nu_of_sib=rd.choices(n,weights=[7,8,7,3],k=248)

# %%
df['Number of Siblings']=nu_of_sib
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings Father Education Mother Education School Distance  \
# 0                NaN              NaN              NaN             NaN
# 1                NaN              NaN              NaN             NaN
# 2                NaN              NaN              NaN             NaN
# 3                NaN              NaN              NaN             NaN
# 4                NaN              NaN              NaN             NaN
#
#   Means to school House Lighting School Infrustructure School Meal per day  \
# 0             NaN            NaN                   NaN                 NaN
# 1             NaN            NaN                   NaN                 NaN
# 2             NaN            NaN                   NaN                 NaN
# 3             NaN            NaN                   NaN                 NaN
# 4             NaN            NaN                   NaN                 NaN
#
#   School Cost Student marks Family income source Class Label  \
# 0         NaN           NaN                  NaN         NaN
# 1         NaN           NaN                  NaN         NaN
# 2         NaN           NaN                  NaN         NaN
# 3         NaN           NaN                  NaN         NaN
# 4         NaN           NaN                  NaN         NaN
#
#   Number of Siblings
# 0     Three Children
# 1       Four or more
# 2       Two Children
# 3       Two Children
# 4       Four or more

# %%
n=["None","primary","secondary","Honor’s/ Equivalent ","Master’s/ Equivalent and above"]
fa_edu=rd.choices(n,weights=[7,8,7,3,2],k=248)

# %%
df['Father Education'] = fa_edu
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education Mother Education  \
# 0                NaN                            None              NaN
# 1                NaN  Master’s/ Equivalent and above              NaN
# 2                NaN                       secondary              NaN
# 3                NaN            Honor’s/ Equivalent               NaN
# 4                NaN                       secondary              NaN
#
#   School Distance Means to school House Lighting School Infrustructure  \
# 0             NaN             NaN            NaN                   NaN
# 1             NaN             NaN            NaN                   NaN
# 2             NaN             NaN            NaN                   NaN
# 3             NaN             NaN            NaN                   NaN
# 4             NaN             NaN            NaN                   NaN
#
#   School Meal per day School Cost Student marks Family income source  \
# 0                 NaN         NaN           NaN                  NaN
# 1                 NaN         NaN           NaN                  NaN
# 2                 NaN         NaN           NaN                  NaN
# 3                 NaN         NaN           NaN                  NaN
# 4                 NaN         NaN           NaN                  NaN
#
#   Class Label Number of Siblings
# 0         NaN     Three Children
# 1         NaN       Four or more
# 2         NaN       Two Children
# 3         NaN       Two Children
# 4         NaN       Four or more

# %%
n=["None","primary","secondary","Honor’s/ Equivalent ","Master’s/ Equivalent and above"]
mo_edu=rd.choices(n,weights=[7,6,5,3,2],k=248)

# %%
df['Mother Education'] = mo_edu
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance Means to school  \
# 0                            None             NaN             NaN
# 1                            None             NaN             NaN
# 2  Master’s/ Equivalent and above             NaN             NaN
# 3                       secondary             NaN             NaN
# 4                       secondary             NaN             NaN
#
#   House Lighting School Infrustructure School Meal per day School Cost  \
# 0            NaN                   NaN                 NaN         NaN
# 1            NaN                   NaN                 NaN         NaN
# 2            NaN                   NaN                 NaN         NaN
# 3            NaN                   NaN                 NaN         NaN
# 4            NaN                   NaN                 NaN         NaN
#
#   Student marks Family income source Class Label Number of Siblings
# 0           NaN                  NaN         NaN     Three Children
# 1           NaN                  NaN         NaN       Four or more
# 2           NaN                  NaN         NaN       Two Children
# 3           NaN                  NaN         NaN       Two Children
# 4           NaN                  NaN         NaN       Four or more

# %%
n=["0-0.5 km","0.5-1 km","1-2 km","2-3 km","4-5 km","6-7 km",">7 km"]
sc_dis=rd.choices(n,weights=[8,6,7,5,4,3,2],k=248)

# %%
df['School Distance']= sc_dis
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance Means to school  \
# 0                            None        0–0.5 km             NaN
# 1                            None         2– 3 km             NaN
# 2  Master’s/ Equivalent and above        0–0.5 km             NaN
# 3                       secondary         2– 3 km             NaN
# 4                       secondary        0.5–1 km             NaN
#
#   House Lighting School Infrustructure School Meal per day School Cost  \
# 0            NaN                   NaN                 NaN         NaN
# 1            NaN                   NaN                 NaN         NaN
# 2            NaN                   NaN                 NaN         NaN
# 3            NaN                   NaN                 NaN         NaN
# 4            NaN                   NaN                 NaN         NaN
#
#   Student marks Family income source Class Label Number of Siblings
# 0           NaN                  NaN         NaN     Three Children
# 1           NaN                  NaN         NaN       Four or more
# 2           NaN                  NaN         NaN       Two Children
# 3           NaN                  NaN         NaN       Two Children
# 4           NaN                  NaN         NaN       Four or more

# %%
n=["Walk","Bicycle/motorbike","School Bus/Bus","Private car","Rickshaw"]
means_to_sc=rd.choices(n,weights=[7,6,5,2,3],k=248)

# %%
df['Means to school']= means_to_sc
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance    Means to school  \
# 0                            None        0–0.5 km               Walk
# 1                            None         2– 3 km     School Bus/Bus
# 2  Master’s/ Equivalent and above        0–0.5 km        Private car
# 3                       secondary         2– 3 km  Bicycle/motorbike
# 4                       secondary        0.5–1 km     School Bus/Bus
#
#   House Lighting School Infrustructure School Meal per day School Cost  \
# 0            NaN                   NaN                 NaN         NaN
# 1            NaN                   NaN                 NaN         NaN
# 2            NaN                   NaN                 NaN         NaN
# 3            NaN                   NaN                 NaN         NaN
# 4            NaN                   NaN                 NaN         NaN
#
#   Student marks Family income source Class Label Number of Siblings
# 0           NaN                  NaN         NaN     Three Children
# 1           NaN                  NaN         NaN       Four or more
# 2           NaN                  NaN         NaN       Two Children
# 3           NaN                  NaN         NaN       Two Children
# 4           NaN                  NaN         NaN       Four or more

# %%
n=["Electricity","Solar","Paraffin","Other" ]
hou_light=rd.choices(n,weights=[8,6,5,2],k=248)

# %%
df['House Lighting']=hou_light
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance    Means to school  \
# 0                            None        0–0.5 km               Walk
# 1                            None         2– 3 km     School Bus/Bus
# 2  Master’s/ Equivalent and above        0–0.5 km        Private car
# 3                       secondary         2– 3 km  Bicycle/motorbike
# 4                       secondary        0.5–1 km     School Bus/Bus
#
#   House Lighting School Infrustructure School Meal per day School Cost  \
# 0    Electricity                   NaN                 NaN         NaN
# 1          Solar                   NaN                 NaN         NaN
# 2          Other                   NaN                 NaN         NaN
# 3       Paraffin                   NaN                 NaN         NaN
# 4          Solar                   NaN                 NaN         NaN
#
#   Student marks Family income source Class Label Number of Siblings
# 0           NaN                  NaN         NaN     Three Children
# 1           NaN                  NaN         NaN       Four or more
# 2           NaN                  NaN         NaN       Two Children
# 3           NaN                  NaN         NaN       Two Children
# 4           NaN                  NaN         NaN       Four or more

# %%
n=["Toilet","Water","Teaching facilities","Electricity"]
school_infra=rd.choices(n,weights=[8,6,3,8],k=248)

# %%
df['School Infrustructure']=school_infra
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance    Means to school  \
# 0                            None        0–0.5 km               Walk
# 1                            None         2– 3 km     School Bus/Bus
# 2  Master’s/ Equivalent and above        0–0.5 km        Private car
# 3                       secondary         2– 3 km  Bicycle/motorbike
# 4                       secondary        0.5–1 km     School Bus/Bus
#
#   House Lighting School Infrustructure School Meal per day School Cost  \
# 0    Electricity   Teaching facilities                 NaN         NaN
# 1          Solar           Electricity                 NaN         NaN
# 2          Other                 Water                 NaN         NaN
# 3       Paraffin           Electricity                 NaN         NaN
# 4          Solar                 Water                 NaN         NaN
#
#   Student marks Family income source Class Label Number of Siblings
# 0           NaN                  NaN         NaN     Three Children
# 1           NaN                  NaN         NaN       Four or more
# 2           NaN                  NaN         NaN       Two Children
# 3           NaN                  NaN         NaN       Two Children
# 4           NaN                  NaN         NaN       Four or more

# %%
n=["None","Once","Two Times","Three Times or more"]
sc_mealperday=rd.choices(n,weights=[8,4,0,0],k=248)

# %%
df['School Meal per day']=sc_mealperday
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance    Means to school  \
# 0                            None        0–0.5 km               Walk
# 1                            None         2– 3 km     School Bus/Bus
# 2  Master’s/ Equivalent and above        0–0.5 km        Private car
# 3                       secondary         2– 3 km  Bicycle/motorbike
# 4                       secondary        0.5–1 km     School Bus/Bus
#
#   House Lighting School Infrustructure School Meal per day School Cost  \
# 0    Electricity   Teaching facilities                Once         NaN
# 1          Solar           Electricity                Once         NaN
# 2          Other                 Water                None         NaN
# 3       Paraffin           Electricity                None         NaN
# 4          Solar                 Water                None         NaN
#
#   Student marks Family income source Class Label Number of Siblings
# 0           NaN                  NaN         NaN     Three Children
# 1           NaN                  NaN         NaN       Four or more
# 2           NaN                  NaN         NaN       Two Children
# 3           NaN                  NaN         NaN       Two Children
# 4           NaN                  NaN         NaN       Four or more

# %%
n=["Low","Mediam","High"]
sc_cost=rd.choices(n,weights=[4,5,7],k=248)

# %%
df['School Cost']=sc_cost
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance    Means to school  \
# 0                            None        0–0.5 km               Walk
# 1                            None         2– 3 km     School Bus/Bus
# 2  Master’s/ Equivalent and above        0–0.5 km        Private car
# 3                       secondary         2– 3 km  Bicycle/motorbike
# 4                       secondary        0.5–1 km     School Bus/Bus
#
#   House Lighting School Infrustructure School Meal per day School Cost  \
# 0    Electricity   Teaching facilities                Once         Low
# 1          Solar           Electricity                Once         Low
# 2          Other                 Water                None        High
# 3       Paraffin           Electricity                None         Low
# 4          Solar                 Water                None        High
#
#   Student marks Family income source Class Label Number of Siblings
# 0           NaN                  NaN         NaN     Three Children
# 1           NaN                  NaN         NaN       Four or more
# 2           NaN                  NaN         NaN       Two Children
# 3           NaN                  NaN         NaN       Two Children
# 4           NaN                  NaN         NaN       Four or more

# %%
n=["Formal wage","Transfers","Own business","Farming","Casual wage","Pension"]
fa_in_sou=rd.choices(n,weights=[8,5,6,5,7,3],k=248)

# %%
df['Family income source']=fa_in_sou
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance    Means to school  \
# 0                            None        0–0.5 km               Walk
# 1                            None         2– 3 km     School Bus/Bus
# 2  Master’s/ Equivalent and above        0–0.5 km        Private car
# 3                       secondary         2– 3 km  Bicycle/motorbike
# 4                       secondary        0.5–1 km     School Bus/Bus
#
#   House Lighting School Infrustructure School Meal per day School Cost  \
# 0    Electricity   Teaching facilities                Once         Low
# 1          Solar           Electricity                Once         Low
# 2          Other                 Water                None        High
# 3       Paraffin           Electricity                None         Low
# 4          Solar                 Water                None        High
#
#   Student marks Family income source Class Label Number of Siblings
# 0           NaN         Own business         NaN     Three Children
# 1           NaN              Farming         NaN       Four or more
# 2           NaN              Farming         NaN       Two Children
# 3           NaN          Casual wage         NaN       Two Children
# 4           NaN              Farming         NaN       Four or more

# %%
df.rename(columns={'Student marks':'GPA'},inplace =True)

# %%
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance    Means to school  \
# 0                            None        0–0.5 km               Walk
# 1                            None         2– 3 km     School Bus/Bus
# 2  Master’s/ Equivalent and above        0–0.5 km        Private car
# 3                       secondary         2– 3 km  Bicycle/motorbike
# 4                       secondary        0.5–1 km     School Bus/Bus
#
#   House Lighting School Infrustructure School Meal per day School Cost  GPA  \
# 0    Electricity   Teaching facilities                Once         Low  NaN
# 1          Solar           Electricity                Once         Low  NaN
# 2          Other                 Water                None        High  NaN
# 3       Paraffin           Electricity                None         Low  NaN
# 4          Solar                 Water                None        High  NaN
#
#   Family income source Class Label Number of Siblings
# 0         Own business         NaN     Three Children
# 1              Farming         NaN       Four or more
# 2              Farming         NaN       Two Children
# 3          Casual wage         NaN       Two Children
# 4              Farming         NaN       Four or more

# %%
gpa=rd.uniform(2.3,5.0)

# %%
gpa
# Out:
# 4.70171560452817

# %%
result = []
for i in range(0,248):
  result.append(rd.randint(20,92))

# %%
result
# Out:
# [36,
#  40,
#  77,
#  89,
#  50,
#  80,
#  51,
#  42,
#  77,
#  59,
#  24,
#  89,
#  83,
#  41,
#  35,
#  46,
#  65,
#  40,
#  36,
#  72,
#  45,
#  34,
#  74,
#  40,
#  57,
#  46,
#  41,
#  82,
#  91,
#  78,
#  63,
#  90,
#  32,
#  31,
#  37,
#  52,
#  62,
#  65,
#  88,
#  77,
#  33,
#  56,
#  74,
#  32,
#  71,
#  79,
#  66,
#  66,
#  46,
#  40,
#  56,
#  86,
#  83,
#  75,
#  30,
#  69,
#  91,
#  22,
#  38,
#  43,
#  28,
#  86,
#  30,
#  70,
#  55,
#  72,
#  83,
#  66,
#  27,
#  78,
#  57,
#  25,
#  63,
#  49,
#  91,
#  80,
#  28,
#  34,
#  46,
#  61,
#  65,
#  71,
#  71,
#  35,
#  39,
#  71,
#  62,
#  66,
#  31,
#  77,
#  60,
#  89,
#  55,
#  35,
#  62,
#  39,
#  61,
#  40,
#  27,
#  69,
#  88,
#  82,
#  90,
#  55,
#  46,
#  39,
#  55,
#  41,
#  31,
#  84,
#  20,
#  58,
#  88,
#  59,
#  85,
#  36,
#  80,
#  87,
#  70,
#  52,
#  57,
#  66,
#  57,
#  79,
#  65,
#  52,
#  51,
#  50,
#  25,
#  82,
#  58,
#  59,
#  77,
#  69,
#  79,
#  88,
#  66,
#  49,
#  73,
#  67,
#  39,
#  76,
#  77,
#  52,
#  61,
#  20,
#  44,
#  89,
#  27,
#  34,
#  82,
#  79,
#  86,
#  64,
#  80,
#  50,
#  80,
#  44,
#  44,
#  87,
#  65,
#  41,
#  55,
#  71,
#  53,
#  27,
#  65,
#  86,
#  28,
#  80,
#  26,
#  29,
#  45,
#  46,
#  85,
#  21,
#  83,
#  75,
#  92,
#  37,
#  38,
#  54,
#  60,
#  61,
#  83,
#  70,
#  24,
#  68,
#  78,
#  54,
#  43,
#  51,
#  89,
#  82,
#  40,
#  74,
#  56,
#  78,
#  29,
#  71,
#  67,
#  25,
#  61,
#  51,
#  74,
#  77,
#  52,
#  43,
#  65,
#  75,
#  48,
#  43,
#  87,
#  55,
#  72,
#  50,
#  78,
#  92,
#  60,
#  61,
#  28,
#  79,
#  79,
#  88,
#  53,
#  32,
#  87,
#  85,
#  73,
#  37,
#  76,
#  51,
#  82,
#  26,
#  21,
#  55,
#  67,
#  31,
#  62,
#  34,
#  50,
#  45,
#  61,
#  47,
#  56,
#  20,
#  33,
#  76]

# %%
subjects = pd.DataFrame(columns=["Bangla","English", "Math","Science","History","Social Science","Religious Study"])

# %%
subjects.head()
# Out:
# Empty DataFrame
# Columns: [Bangla, English, Math, Science, History, Social Science, Religious Study]
# Index: []

# %%
for j in subjects.columns:
  result = []
  for i in range(0,248):
    result.append(rd.randint(20,92))
  subjects[j]=result

# %%
subjects
# Out:
#      Bangla  English  Math  Science  History  Social Science  Religious Study
# 0        86       68    88       46       61              65               33
# 1        34       41    63       84       34              49               33
# 2        67       70    40       54       86              71               69
# 3        57       88    77       23       83              48               67
# 4        77       24    45       44       40              86               52
# ..      ...      ...   ...      ...      ...             ...              ...
# 243      66       85    77       32       87              25               64
# 244      57       85    70       78       87              72               20
# 245      46       79    80       31       51              54               24
# 246      77       44    65       31       88              62               91
# 247      54       77    49       55       90              77               26
#
# [248 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    248 non-null    object
#  1   Gender                 248 non-null    object
#  2   Home Language          248 non-null    object
#  3   Father Occupation      248 non-null    object
#  4   Mother Occupation      248 non-null    object
#  5   Number Of Siblings     0 non-null      object
#  6   Father Education       248 non-null    object
#  7   Mother Education       248 non-null    object
#  8   School Distance        248 non-null    object
#  9   Means to school        248 non-null    object
#  10  House Lighting         248 non-null    object
#  11  School Infrustructure  248 non-null    object
#  12  School Meal per day    248 non-null    object
#  13  School Cost            248 non-null    object
#  14  GPA                    0 non-null      object
#  15  Family income source   248 non-null    object
#  16  Class Label            0 non-null      object
#  17  Number of Siblings     248 non-null    object
# dtypes: object(18)
# memory usage: 35.0+ KB

# %%
new_df=pd.concat([df, subjects], axis=1)
new_df
# Out:
#              Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0    10-13 years  female  Native Language        Unemployed       Agriculture
# 1    10-13 years  female  Native Language         Immigrant    Private sector
# 2    10-13 years  female  Native Language    Private sector         Immigrant
# 3    15-18 years    male           Bangla    Private sector          Business
# 4    10-13 years    male  Native Language       Freelancer      Public sector
# ..           ...     ...              ...               ...               ...
# 243  15-18 years  female  Native Language         Immigrant          Business
# 244  10-13 years  female           Bangla         Immigrant          Business
# 245  15-18 years    male  Native Language         Immigrant        Home maker
# 246  10-13 years  female  Native Language    Private sector       Agriculture
# 247  10-13 years  female           Bangla          Business     Public sector
#
#     Number Of Siblings                Father Education  \
# 0                  NaN                            None
# 1                  NaN  Master’s/ Equivalent and above
# 2                  NaN                       secondary
# 3                  NaN            Honor’s/ Equivalent
# 4                  NaN                       secondary
# ..                 ...                             ...
# 243                NaN                       secondary
# 244                NaN                       secondary
# 245                NaN            Honor’s/ Equivalent
# 246                NaN                         primary
# 247                NaN  Master’s/ Equivalent and above
#
#                    Mother Education School Distance    Means to school  ...  \
# 0                              None        0–0.5 km               Walk  ...
# 1                              None         2– 3 km     School Bus/Bus  ...
# 2    Master’s/ Equivalent and above        0–0.5 km        Private car  ...
# 3                         secondary         2– 3 km  Bicycle/motorbike  ...
# 4                         secondary        0.5–1 km     School Bus/Bus  ...
# ..                              ...             ...                ...  ...
# 243                            None           >7 km               Walk  ...
# 244            Honor’s/ Equivalent         0.5–1 km               Walk  ...
# 245            Honor’s/ Equivalent           1–2 km        Private car  ...
# 246            Honor’s/ Equivalent         0.5–1 km               Walk  ...
# 247                            None          1–2 km  Bicycle/motorbike  ...
#
#     Family income source Class Label Number of Siblings Bangla English Math  \
# 0           Own business         NaN     Three Children     86      68   88
# 1                Farming         NaN       Four or more     34      41   63
# 2                Farming         NaN       Two Children     67      70   40
# 3            Casual wage         NaN       Two Children     57      88   77
# 4                Farming         NaN       Four or more     77      24   45
# ..                   ...         ...                ...    ...     ...  ...
# 243          Casual wage         NaN               None     66      85   77
# 244         Own business         NaN     Three Children     57      85   70
# 245          Casual wage         NaN               None     46      79   80
# 246            Transfers         NaN       Four or more     77      44   65
# 247              Farming         NaN               None     54      77   49
#
#     Science History  Social Science  Religious Study
# 0        46      61              65               33
# 1        84      34              49               33
# 2        54      86              71               69
# 3        23      83              48               67
# 4        44      40              86               52
# ..      ...     ...             ...              ...
# 243      32      87              25               64
# 244      78      87              72               20
# 245      31      51              54               24
# 246      31      88              62               91
# 247      55      90              77               26
#
# [248 rows x 25 columns]

# %%
new_df.columns
# Out:
# Index(['Age', 'Gender', 'Home Language', 'Father Occupation',
#        'Mother Occupation', 'Number Of Siblings', 'Father Education',
#        'Mother Education', 'School Distance', 'Means to school',
#        'House Lighting', 'School Infrustructure', 'School Meal per day',
#        'School Cost', 'GPA', 'Family income source', 'Class Label',
#        'Number of Siblings', 'Bangla', 'English', 'Math', 'Science', 'History',
#        'Social Science', 'Religious Study'],
#       dtype='object')

# %%
df['GPA']=round((new_df[['Bangla', 'English', 'Math', 'Science', 'History','Social Science', 'Religious Study']].sum(axis=1)/7)/20,2)

# %%
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance    Means to school  \
# 0                            None        0–0.5 km               Walk
# 1                            None         2– 3 km     School Bus/Bus
# 2  Master’s/ Equivalent and above        0–0.5 km        Private car
# 3                       secondary         2– 3 km  Bicycle/motorbike
# 4                       secondary        0.5–1 km     School Bus/Bus
#
#   House Lighting School Infrustructure School Meal per day School Cost   GPA  \
# 0    Electricity   Teaching facilities                Once         Low  3.19
# 1          Solar           Electricity                Once         Low  2.41
# 2          Other                 Water                None        High  3.26
# 3       Paraffin           Electricity                None         Low  3.16
# 4          Solar                 Water                None        High  2.63
#
#   Family income source Class Label Number of Siblings
# 0         Own business         NaN     Three Children
# 1              Farming         NaN       Four or more
# 2              Farming         NaN       Two Children
# 3          Casual wage         NaN       Two Children
# 4              Farming         NaN       Four or more

# %%
df.isnull()
# Out:
#        Age  Gender  Home Language  Father Occupation  Mother Occupation  \
# 0    False   False          False              False              False
# 1    False   False          False              False              False
# 2    False   False          False              False              False
# 3    False   False          False              False              False
# 4    False   False          False              False              False
# ..     ...     ...            ...                ...                ...
# 243  False   False          False              False              False
# 244  False   False          False              False              False
# 245  False   False          False              False              False
# 246  False   False          False              False              False
# 247  False   False          False              False              False
#
#      Number Of Siblings  Father Education  Mother Education  School Distance  \
# 0                  True             False             False            False
# 1                  True             False             False            False
# 2                  True             False             False            False
# 3                  True             False             False            False
# 4                  True             False             False            False
# ..                  ...               ...               ...              ...
# 243                True             False             False            False
# 244                True             False             False            False
# 245                True             False             False            False
# 246                True             False             False            False
# 247                True             False             False            False
#
#      Means to school  House Lighting  School Infrustructure  \
# 0              False           False                  False
# 1              False           False                  False
# 2              False           False                  False
# 3              False           False                  False
# 4              False           False                  False
# ..               ...             ...                    ...
# 243            False           False                  False
# 244            False           False                  False
# 245            False           False                  False
# 246            False           False                  False
# 247            False           False                  False
#
#      School Meal per day  School Cost    GPA  Family income source  \
# 0                  False        False  False                 False
# 1                  False        False  False                 False
# 2                  False        False  False                 False
# 3                  False        False  False                 False
# 4                  False        False  False                 False
# ..                   ...          ...    ...                   ...
# 243                False        False  False                 False
# 244                False        False  False                 False
# 245                False        False  False                 False
# 246                False        False  False                 False
# 247                False        False  False                 False
#
#      Class Label  Number of Siblings
# 0           True               False
# 1           True               False
# 2           True               False
# 3           True               False
# 4           True               False
# ..           ...                 ...
# 243         True               False
# 244         True               False
# 245         True               False
# 246         True               False
# 247         True               False
#
# [248 rows x 18 columns]

# %%
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  10-13 years  female  Native Language        Unemployed       Agriculture
# 1  10-13 years  female  Native Language         Immigrant    Private sector
# 2  10-13 years  female  Native Language    Private sector         Immigrant
# 3  15-18 years    male           Bangla    Private sector          Business
# 4  10-13 years    male  Native Language       Freelancer      Public sector
#
#   Number Of Siblings                Father Education  \
# 0                NaN                            None
# 1                NaN  Master’s/ Equivalent and above
# 2                NaN                       secondary
# 3                NaN            Honor’s/ Equivalent
# 4                NaN                       secondary
#
#                  Mother Education School Distance    Means to school  \
# 0                            None        0–0.5 km               Walk
# 1                            None         2– 3 km     School Bus/Bus
# 2  Master’s/ Equivalent and above        0–0.5 km        Private car
# 3                       secondary         2– 3 km  Bicycle/motorbike
# 4                       secondary        0.5–1 km     School Bus/Bus
#
#   House Lighting School Infrustructure School Meal per day School Cost   GPA  \
# 0    Electricity   Teaching facilities                Once         Low  3.19
# 1          Solar           Electricity                Once         Low  2.41
# 2          Other                 Water                None        High  3.26
# 3       Paraffin           Electricity                None         Low  3.16
# 4          Solar                 Water                None        High  2.63
#
#   Family income source Class Label Number of Siblings
# 0         Own business         NaN     Three Children
# 1              Farming         NaN       Four or more
# 2              Farming         NaN       Two Children
# 3          Casual wage         NaN       Two Children
# 4              Farming         NaN       Four or more

# %%
df.to_csv('studendos.csv',encoding='UTF-8')
