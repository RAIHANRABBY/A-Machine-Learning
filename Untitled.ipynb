# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Student_drop_out_system.csv')
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  13-15 years  female  Native Language         Immigrant        Home maker
# 1  10-13 years    male           Bangla       Freelancer         Home maker
# 2  13-15 years  female  Native Language    Private sector        Home maker
# 3  13-15 years  female           Bangla     Public sector        Freelancer
# 4  10-13 years    male  Native Language     Public sector        Home maker
#
#   Number Of Siblings     Father Education Mother Education School Distance  \
# 0       Four or more            secondary        secondary          1-2 km
# 1     Three Children  Honors/ Equivalent         secondary        0.5-1 km
# 2     Three Children              primary        secondary           >7 km
# 3     Three Children              primary        secondary        0-0.5 km
# 4               None  Honors/ Equivalent           primary          1-2 km
#
# ...

# %%
import random as r

# %%
df['Class Label']=r.choices(['Yes','No'],weights=(8,6),k=248)

# %%
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  13-15 years  female  Native Language         Immigrant        Home maker
# 1  10-13 years    male           Bangla       Freelancer         Home maker
# 2  13-15 years  female  Native Language    Private sector        Home maker
# 3  13-15 years  female           Bangla     Public sector        Freelancer
# 4  10-13 years    male  Native Language     Public sector        Home maker
#
#   Number Of Siblings     Father Education Mother Education School Distance  \
# 0       Four or more            secondary        secondary          1-2 km
# 1     Three Children  Honors/ Equivalent         secondary        0.5-1 km
# 2     Three Children              primary        secondary           >7 km
# 3     Three Children              primary        secondary        0-0.5 km
# 4               None  Honors/ Equivalent           primary          1-2 km
#
# ...

# %%
df.to_csv('test_sdos.csv')

# %%
df_old=pd.read_csv('Student_drop_out_system.csv')

# %%
df_old
# Out:
#              Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0    13-15 years  female  Native Language         Immigrant        Home maker
# 1    10-13 years    male           Bangla       Freelancer         Home maker
# 2    13-15 years  female  Native Language    Private sector        Home maker
# 3    13-15 years  female           Bangla     Public sector        Freelancer
# 4    10-13 years    male  Native Language     Public sector        Home maker
# ..           ...     ...              ...               ...               ...
# 243  13-15 years  female  Native Language    Private sector        Home maker
# 244  10-13 years    male           Bangla     Public sector        Home maker
# 245  10-13 years  female  Native Language    Private sector          Business
# 246  13-15 years  female           Bangla    Private sector        Home maker
# 247  10-13 years  female  Native Language    Private sector        Home maker
#
# ...

# %%
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  13-15 years  female  Native Language         Immigrant        Home maker
# 1  10-13 years    male           Bangla       Freelancer         Home maker
# 2  13-15 years  female  Native Language    Private sector        Home maker
# 3  13-15 years  female           Bangla     Public sector        Freelancer
# 4  10-13 years    male  Native Language     Public sector        Home maker
#
#   Number Of Siblings     Father Education Mother Education School Distance  \
# 0       Four or more            secondary        secondary          1-2 km
# 1     Three Children  Honors/ Equivalent         secondary        0.5-1 km
# 2     Three Children              primary        secondary           >7 km
# 3     Three Children              primary        secondary        0-0.5 km
# 4               None  Honors/ Equivalent           primary          1-2 km
#
# ...

# %%
add_df=df.iloc[:50,:]
add_df
# Out:
#                Age  Gender    Home Language Father Occupation  \
# 0      13-15 years  female  Native Language         Immigrant
# 1      10-13 years    male           Bangla       Freelancer
# 2      13-15 years  female  Native Language    Private sector
# 3      13-15 years  female           Bangla     Public sector
# 4      10-13 years    male  Native Language     Public sector
# 5      10-13 years    male           Bangla        Unemployed
# 6      10-13 years  female  Native Language    Private sector
# 7      13-15 years  female           Bangla            Worker
# 8      10-13 years    male  Native Language    Private sector
# 9      10-13 years  female  Native Language    Private sector
# 10     13-15 years    male  Native Language            Worker
# 11     13-15 years    male           Bangla    Private sector
# 12     15-18 years    male  Native Language       Agriculture
# 13     13-15 years  female          English            Worker
# ...

# %%
add_df.shape
# Out:
# (50, 28)

# %%
df_old.shape
# Out:
# (248, 28)

# %%
final_df=df_old.append(add_df)

# %%
df_old
# Out:
#              Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0    13-15 years  female  Native Language         Immigrant        Home maker
# 1    10-13 years    male           Bangla       Freelancer         Home maker
# 2    13-15 years  female  Native Language    Private sector        Home maker
# 3    13-15 years  female           Bangla     Public sector        Freelancer
# 4    10-13 years    male  Native Language     Public sector        Home maker
# ..           ...     ...              ...               ...               ...
# 243  13-15 years  female  Native Language    Private sector        Home maker
# 244  10-13 years    male           Bangla     Public sector        Home maker
# 245  10-13 years  female  Native Language    Private sector          Business
# 246  13-15 years  female           Bangla    Private sector        Home maker
# 247  10-13 years  female  Native Language    Private sector        Home maker
#
# ...

# %%
final_df.shape
# Out:
# (298, 28)

# %%
final_df.to_csv('improvedSDOS.csv')
