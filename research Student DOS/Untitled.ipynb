# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('sample2.csv')
df.head()
# Out:
#    Unnamed: 0          Age  Gender    Home Language Father Occupation  \
# 0           0  10-13 years  female  Native Language    Private sector
# 1           1  13-15 years  female  Native Language        Unemployed
# 2           2  10-13 years  female  Native Language          Business
# 3           3  10-13 years    male  Native Language    Private sector
# 4           4  13-15 years  female  Native Language         Immigrant
#
#   Mother Occupation Number Of Siblings     Father Education  \
# 0        Home maker       Four or more  Honors/ Equivalent
# 1        Home maker       Four or more            secondary
# 2            Worker               None              primary
# 3        Home maker       Four or more  Honors/ Equivalent
# 4       Agriculture       Two Children            secondary
#
#      Mother Education School Distance  ... Bangla English Math Science  \
# 0             primary        0.5-1 km  ...     60      75   70      38
# ...

# %%
import random as r

# %%
df['Class Label']=r.choices(['Yes','No'],weights=(8,6),k=1000)

# %%
df.head()
# Out:
#    Unnamed: 0          Age  Gender    Home Language Father Occupation  \
# 0           0  10-13 years  female  Native Language    Private sector
# 1           1  13-15 years  female  Native Language        Unemployed
# 2           2  10-13 years  female  Native Language          Business
# 3           3  10-13 years    male  Native Language    Private sector
# 4           4  13-15 years  female  Native Language         Immigrant
#
#   Mother Occupation Number Of Siblings     Father Education  \
# 0        Home maker       Four or more  Honors/ Equivalent
# 1        Home maker       Four or more            secondary
# 2            Worker               None              primary
# 3        Home maker       Four or more  Honors/ Equivalent
# 4       Agriculture       Two Children            secondary
#
#      Mother Education School Distance  ... Bangla English Math Science  \
# 0             primary        0.5-1 km  ...     60      75   70      38
# ...

# %%
df_old=pd.read_csv('sample2.csv')

# %%
df_old
# Out:
#      Unnamed: 0          Age  Gender    Home Language Father Occupation  \
# 0             0  10-13 years  female  Native Language    Private sector
# 1             1  13-15 years  female  Native Language        Unemployed
# 2             2  10-13 years  female  Native Language          Business
# 3             3  10-13 years    male  Native Language    Private sector
# 4             4  13-15 years  female  Native Language         Immigrant
# ..          ...          ...     ...              ...               ...
# 995         995  15-18 years    male  Native Language       Agriculture
# 996         996  10-13 years  female  Native Language    Private sector
# 997         997  10-13 years    male          English    Private sector
# 998         998  10-13 years  female  Native Language            Worker
# 999         999  10-13 years  female  Native Language    Private sector
#
#     Mother Occupation Number Of Siblings     Father Education  \
# ...

# %%
df.head()
# Out:
#            Age  Gender    Home Language Father Occupation Mother Occupation  \
# 0  13-15 years  female  Native Language         Immigrant        Home maker
# 1  10-13 years    male           Bangla       Freelancer         Home maker
# 2  13-15 years  female  Native Language    Private sector        Home maker
# 3  13-15 years  female           Bangla     Public sector        Freelancer
# 4  10-13 years    male  Native Language     Public sector        Home maker
#
#   Number Of Siblings     Father Education Mother Education School Distance  \
# 0       Four or more            secondary        secondary          1-2 km
# 1     Three Children  Honors/ Equivalent         secondary        0.5-1 km
# 2     Three Children              primary        secondary           >7 km
# 3     Three Children              primary        secondary        0-0.5 km
# 4               None  Honors/ Equivalent           primary          1-2 km
#
# ...

# %%
add_df=df.iloc[:100,:]
add_df
# Out:
#     Unnamed: 0          Age  Gender    Home Language Father Occupation  \
# 0            0  10-13 years  female  Native Language    Private sector
# 1            1  13-15 years  female  Native Language        Unemployed
# 2            2  10-13 years  female  Native Language          Business
# 3            3  10-13 years    male  Native Language    Private sector
# 4            4  13-15 years  female  Native Language         Immigrant
# ..         ...          ...     ...              ...               ...
# 95          95  10-13 years  female           Bangla         Immigrant
# 96          96  10-13 years    male  Native Language            Worker
# 97          97  13-15 years    male  Native Language        Unemployed
# 98          98  15-18 years  female  Native Language     Public sector
# 99          99  15-18 years  female          English        Unemployed
#
#    Mother Occupation Number Of Siblings     Father Education  \
# ...

# %%
add_df.shape
# Out:
# (100, 28)

# %%
df_old.shape
# Out:
# (1000, 28)

# %%
final_df=df_old.append(add_df)

# %%
final_df.shape
# Out:
# (1100, 28)

# %%
final_df['Home Language']
# Out:
# 0     Native Language
# 1     Native Language
# 2     Native Language
# 3     Native Language
# 4     Native Language
#            ...
# 95             Bangla
# 96    Native Language
# 97    Native Language
# 98    Native Language
# 99            English
# Name: Home Language, Length: 1100, dtype: object

# %%
lang=r.choices(['Bangla','English'],weights=(9,.9),k=1100)

# %%
lang.count('Bangla')
# Out:
# 1008

# %%
lang.count('English')
# Out:
# 92

# %%
final_df['Home Language']=lang

# %%
final_df.head()
# Out:
#    Unnamed: 0          Age  Gender Home Language Father Occupation  \
# 0           0  10-13 years  female        Bangla    Private sector
# 1           1  13-15 years  female        Bangla        Unemployed
# 2           2  10-13 years  female        Bangla          Business
# 3           3  10-13 years    male        Bangla    Private sector
# 4           4  13-15 years  female        Bangla         Immigrant
#
#   Mother Occupation Number Of Siblings     Father Education  \
# 0        Home maker       Four or more  Honors/ Equivalent
# 1        Home maker       Four or more            secondary
# 2            Worker               None              primary
# 3        Home maker       Four or more  Honors/ Equivalent
# 4       Agriculture       Two Children            secondary
#
#      Mother Education School Distance  ... Bangla English Math Science  \
# 0             primary        0.5-1 km  ...     60      75   70      38
# ...

# %%
final_df.to_csv('Improved3SDOS.csv')
